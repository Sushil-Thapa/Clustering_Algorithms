# %%
import numpy as np
from ktree import ktree,KTreeOptions,utils
from pprint import pprint
import pandas as pd

# %%
nn = np.array(len(k.root))
nn
# Out:
# array(1)

# %% [markdown]
# * The time complexity of building K-tree is O(nlogn) where n is the number of bytes of data to cluster
# This is due to the divide and conquer properties inherent to the search tree
# * Standard K-means O(nkdm)
# where, n = no. of data points
# k = no. of clusters
# d = dimensions of data
# m = no. of k-means passses over entire dataset
# * Simple single pass O(nkdm’)
# where m’ = no. of k-means passes over one buffer refill

# %%
sum = 0
clrs = k.root.__len__()
print clrs
for i in range(clrs):
    x = nn[i,1].__len__()
    sum += x
#     x
print
sum
# Out:
# 15
# 205

# %%
# pprint(k.root[0].shape)

# %%
nn
# Out:
# array([[array([ 59.78958571,  80.43181429]),
# ...

# %%
# %inline matplotlib
import matplotlib.pyplot as plt

dataset = nn
xValues = data.iloc[:,0:1]
yValues = data.iloc[:,1:2]

plt.plot(xValues,yValues,label=algorithm)
plt.pause(2)

# %%
100/3
# Out:
# 33

# %%
ds = np.loadtxt("data/generated_data.csv")  #loads data into numpy n dimensional array
N,d = ds.shape
print N,d
options = KTreeOptions() #sets options for ktree_clustering
options.order = 100
options.weighted = True
options.distance = "euclidean"
options.reinsert = True

k = ktree(data=ds, options=options)

# %%
ds = np.loadtxt("data/generated_data_1000.csv")
print ds.shape

# %%
utils.save_ktree(k,'save_ktree.pickle') #Save Pickle

# %%
k = utils.load_ktree('save_ktree.pickle')
